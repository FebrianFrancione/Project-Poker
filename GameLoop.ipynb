# %%
from pypokerengine.api.game import setup_config, start_poker
from HonestPlayer import HonestPlayer
from RLPokerPlayer import RLPokerAgent
from BluffingPlayer import BluffingPlayer
import numpy as np
import matplotlib.pyplot as plt

def plot_rewards(reward_list, subtitle):
    number_of_rounds = len(reward_list)
    rounds_list = np.arange(1, number_of_rounds + 1)
    plt.title('Training Reward over time ' + subtitle)
    plt.ylabel('Reward')
    plt.xlabel('Rounds')
    cumulative_rewards = np.cumsum(reward_list)
    plt.plot(rounds_list, cumulative_rewards)
    plt.tight_layout()
    plt.show()

def play_game(player1, player2, subtitle, number_rounds):

    total_rewards = []

    for i in range(number_rounds):
        print("********GAME LOOP #" + str(i) + "**********")
        config = setup_config(max_round=1, initial_stack=1000, small_blind_amount=10)
        config.register_player(name="p1", algorithm=player1)
        config.register_player(name="p2", algorithm=player2)
        game_result = start_poker(config, verbose=1)

        rewards_list_from_loop = player1.get_rewards_list()

        total_rewards.extend(rewards_list_from_loop)

        player1.clear_rewards()
        player1.clear_percentage_wins()

    plot_rewards(total_rewards, subtitle)

    
# declare our players
RLPokerPlayer = RLPokerAgent()
HonestPlayer = HonestPlayer()

# re initialize RL player each game so it's not continuing to modify itself after previous experiment
play_game(RLPokerPlayer, HonestPlayer, "against Honest Player", 1000)

#uncomment for bluffing player and comment out above code
#RLPokerPlayer = RLPokerAgent()
#BluffingPlayer = BluffingPlayer()
#play_game(RLPokerPlayer, BluffingPlayer, "against Bluffing Player", 1000)

#uncomment for RL player and comment out above code
#RLPokerPlayer = RLPokerAgent()
#RLPokerPlayer2 = RLPokerAgent()
#play_game(RLPokerPlayer, RLPokerPlayer2, "against RL Player", 1000)
# Out:
# ********GAME LOOP #0**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['D9', 'DT', 'CJ'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "turn" started. (community card = ['D9', 'DT', 'CJ', 'HT'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "river" started. (community card = ['D9', 'DT', 'CJ', 'HT', 'C7'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 950, 'p2': 1050})
# ********GAME LOOP #1**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['DJ', 'C8', 'D5'])
# Street "turn" started. (community card = ['DJ', 'C8', 'D5', 'C7'])
# Street "river" started. (community card = ['DJ', 'C8', 'D5', 'C7', 'S3'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #2**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['DK', 'H5', 'H8'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1030, 'p2': 970})
# ********GAME LOOP #3**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #4**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #5**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #6**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #7**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #8**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #9**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['CK', 'C6', 'C3'])
# Street "turn" started. (community card = ['CK', 'C6', 'C3', 'DA'])
# Street "river" started. (community card = ['CK', 'C6', 'C3', 'DA', 'H7'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #10**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['D9', 'S7', 'DT'])
# Street "turn" started. (community card = ['D9', 'S7', 'DT', 'HA'])
# Street "river" started. (community card = ['D9', 'S7', 'DT', 'HA', 'D8'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #11**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #12**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #13**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #14**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['SJ', 'D7', 'S4'])
# Street "turn" started. (community card = ['SJ', 'D7', 'S4', 'SK'])
# Street "river" started. (community card = ['SJ', 'D7', 'S4', 'SK', 'DJ'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #15**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['SA', 'C3', 'C7'])
# Street "turn" started. (community card = ['SA', 'C3', 'C7', 'SJ'])
# Street "river" started. (community card = ['SA', 'C3', 'C7', 'SJ', 'D2'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #16**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #17**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['H2', 'C6', 'C4'])
# Street "turn" started. (community card = ['H2', 'C6', 'C4', 'HJ'])
# Street "river" started. (community card = ['H2', 'C6', 'C4', 'HJ', 'SA'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #18**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #19**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #20**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['DA', 'S6', 'DK'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "turn" started. (community card = ['DA', 'S6', 'DK', 'ST'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "river" started. (community card = ['DA', 'S6', 'DK', 'ST', 'S8'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:930"
# "p2" declared "call:930"
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #21**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #22**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #23**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #24**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['C6', 'S5', 'D5'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1030, 'p2': 970})
# ********GAME LOOP #25**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['C6', 'SJ', 'D9'])
# Street "turn" started. (community card = ['C6', 'SJ', 'D9', 'C9'])
# Street "river" started. (community card = ['C6', 'SJ', 'D9', 'C9', 'CJ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #26**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #27**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #28**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #29**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #30**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['CQ', 'C4', 'HA'])
# Street "turn" started. (community card = ['CQ', 'C4', 'HA', 'C9'])
# Street "river" started. (community card = ['CQ', 'C4', 'HA', 'C9', 'CK'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #31**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #32**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #33**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #34**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #35**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['CT', 'D5', 'HK'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "turn" started. (community card = ['CT', 'D5', 'HK', 'CK'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 970, 'p2': 1030})
# ********GAME LOOP #36**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #37**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #38**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['CK', 'D6', 'S2'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:970"
# "p2" declared "call:970"
# Street "turn" started. (community card = ['CK', 'D6', 'S2', 'H6'])
# Street "river" started. (community card = ['CK', 'D6', 'S2', 'H6', 'CJ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #39**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #40**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['HA', 'C8', 'S3'])
# Street "turn" started. (community card = ['HA', 'C8', 'S3', 'CA'])
# Street "river" started. (community card = ['HA', 'C8', 'S3', 'CA', 'S7'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #41**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['CK', 'CJ', 'D7'])
# Street "turn" started. (community card = ['CK', 'CJ', 'D7', 'C2'])
# Street "river" started. (community card = ['CK', 'CJ', 'D7', 'C2', 'S9'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #42**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #43**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['HJ', 'DA', 'H3'])
# Street "turn" started. (community card = ['HJ', 'DA', 'H3', 'SK'])
# Street "river" started. (community card = ['HJ', 'DA', 'H3', 'SK', 'D8'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #44**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #45**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #46**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #47**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #48**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['HT', 'C2', 'D4'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #49**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #50**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['S4', 'C9', 'HK'])
# Street "turn" started. (community card = ['S4', 'C9', 'HK', 'H3'])
# Street "river" started. (community card = ['S4', 'C9', 'HK', 'H3', 'D7'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #51**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #52**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #53**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['H6', 'SJ', 'ST'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 970, 'p2': 1030})
# ********GAME LOOP #54**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #55**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #56**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #57**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #58**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['S5', 'D8', 'SQ'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #59**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #60**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #61**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['C6', 'SA', 'D8'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "turn" started. (community card = ['C6', 'SA', 'D8', 'S6'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "river" started. (community card = ['C6', 'SA', 'D8', 'S6', 'D3'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:950"
# "p2" declared "call:950"
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #62**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #63**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['H4', 'D8', 'C3'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "turn" started. (community card = ['H4', 'D8', 'C3', 'D5'])
# Street "river" started. (community card = ['H4', 'D8', 'C3', 'D5', 'H3'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #64**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #65**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['DT', 'H4', 'D5'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "turn" started. (community card = ['DT', 'H4', 'D5', 'HT'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:960"
# "p2" declared "call:960"
# Street "river" started. (community card = ['DT', 'H4', 'D5', 'HT', 'C7'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #66**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #67**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #68**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #69**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #70**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['CT', 'HA', 'D4'])
# Street "turn" started. (community card = ['CT', 'HA', 'D4', 'D9'])
# Street "river" started. (community card = ['CT', 'HA', 'D4', 'D9', 'H3'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #71**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['SK', 'CJ', 'CA'])
# Street "turn" started. (community card = ['SK', 'CJ', 'CA', 'DK'])
# Street "river" started. (community card = ['SK', 'CJ', 'CA', 'DK', 'S2'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #72**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['D8', 'C6', 'H6'])
# Street "turn" started. (community card = ['D8', 'C6', 'H6', 'CK'])
# Street "river" started. (community card = ['D8', 'C6', 'H6', 'CK', 'D2'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #73**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #74**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['H9', 'CT', 'CA'])
# Street "turn" started. (community card = ['H9', 'CT', 'CA', 'H7'])
# Street "river" started. (community card = ['H9', 'CT', 'CA', 'H7', 'DT'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #75**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #76**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #77**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #78**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['DA', 'H4', 'H9'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1030, 'p2': 970})
# ********GAME LOOP #79**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #80**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #81**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['D3', 'C6', 'H4'])
# Street "turn" started. (community card = ['D3', 'C6', 'H4', 'SQ'])
# Street "river" started. (community card = ['D3', 'C6', 'H4', 'SQ', 'C7'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #82**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #83**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['D6', 'CT', 'H7'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #84**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['SJ', 'D9', 'S5'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "turn" started. (community card = ['SJ', 'D9', 'S5', 'C3'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "river" started. (community card = ['SJ', 'D9', 'S5', 'C3', 'H6'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# "['p2']" won the round 1 (stack = {'p1': 960, 'p2': 1040})
# ********GAME LOOP #85**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #86**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #87**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #88**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #89**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #90**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #91**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #92**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #93**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['H7', 'D6', 'S8'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #94**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #95**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #96**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #97**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #98**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #99**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['SQ', 'C5', 'CT'])
# Street "turn" started. (community card = ['SQ', 'C5', 'CT', 'H3'])
# Street "river" started. (community card = ['SQ', 'C5', 'CT', 'H3', 'S4'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #100**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['HA', 'H9', 'H8'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "turn" started. (community card = ['HA', 'H9', 'H8', 'C8'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "river" started. (community card = ['HA', 'H9', 'H8', 'C8', 'S5'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #101**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['HJ', 'SQ', 'S3'])
# Street "turn" started. (community card = ['HJ', 'SQ', 'S3', 'C3'])
# Street "river" started. (community card = ['HJ', 'SQ', 'S3', 'C3', 'DQ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #102**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['C6', 'D5', 'CT'])
# Street "turn" started. (community card = ['C6', 'D5', 'CT', 'CQ'])
# Street "river" started. (community card = ['C6', 'D5', 'CT', 'CQ', 'C3'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #103**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #104**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #105**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['C6', 'D4', 'CK'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #106**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['CQ', 'H4', 'D3'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "turn" started. (community card = ['CQ', 'H4', 'D3', 'HT'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "river" started. (community card = ['CQ', 'H4', 'D3', 'HT', 'DT'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# "['p2']" won the round 1 (stack = {'p1': 940, 'p2': 1060})
# ********GAME LOOP #107**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #108**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #109**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['S3', 'C7', 'S4'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1030, 'p2': 970})
# ********GAME LOOP #110**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #111**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['SJ', 'HA', 'H8'])
# Street "turn" started. (community card = ['SJ', 'HA', 'H8', 'CJ'])
# Street "river" started. (community card = ['SJ', 'HA', 'H8', 'CJ', 'H6'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #112**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['SK', 'C8', 'DQ'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #113**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #114**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #115**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #116**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['H7', 'H5', 'C9'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "turn" started. (community card = ['H7', 'H5', 'C9', 'D6'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 960, 'p2': 1040})
# ********GAME LOOP #117**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #118**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #119**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #120**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #121**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['HT', 'D9', 'S7'])
# Street "turn" started. (community card = ['HT', 'D9', 'S7', 'DQ'])
# Street "river" started. (community card = ['HT', 'D9', 'S7', 'DQ', 'D7'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #122**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #123**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #124**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['SQ', 'H6', 'C2'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1030, 'p2': 970})
# ********GAME LOOP #125**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['S6', 'H5', 'D8'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "turn" started. (community card = ['S6', 'H5', 'D8', 'S3'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:970"
# "p2" declared "call:970"
# Street "river" started. (community card = ['S6', 'H5', 'D8', 'S3', 'D5'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #126**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['H7', 'D8', 'SQ'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "turn" started. (community card = ['H7', 'D8', 'SQ', 'CA'])
# Street "river" started. (community card = ['H7', 'D8', 'SQ', 'CA', 'C9'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #127**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #128**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['H8', 'S2', 'D4'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# Street "turn" started. (community card = ['H8', 'S2', 'D4', 'HQ'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "river" started. (community card = ['H8', 'S2', 'D4', 'HQ', 'ST'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:950"
# "p2" declared "call:950"
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #129**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['CJ', 'H3', 'S7'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "turn" started. (community card = ['CJ', 'H3', 'S7', 'HT'])
# Street "river" started. (community card = ['CJ', 'H3', 'S7', 'HT', 'C5'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #130**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #131**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #132**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['SJ', 'S5', 'S7'])
# Street "turn" started. (community card = ['SJ', 'S5', 'S7', 'HT'])
# Street "river" started. (community card = ['SJ', 'S5', 'S7', 'HT', 'C9'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #133**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #134**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['SJ', 'DK', 'CA'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "turn" started. (community card = ['SJ', 'DK', 'CA', 'CK'])
# Street "river" started. (community card = ['SJ', 'DK', 'CA', 'CK', 'DJ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #135**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #136**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['S6', 'HQ', 'D6'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "turn" started. (community card = ['S6', 'HQ', 'D6', 'SA'])
# Street "river" started. (community card = ['S6', 'HQ', 'D6', 'SA', 'H6'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #137**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #138**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['DT', 'C2', 'C7'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "turn" started. (community card = ['DT', 'C2', 'C7', 'H6'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "river" started. (community card = ['DT', 'C2', 'C7', 'H6', 'C9'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #139**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #140**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #141**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #142**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #143**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #144**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['H7', 'S3', 'DA'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 970, 'p2': 1030})
# ********GAME LOOP #145**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['HJ', 'DT', 'C8'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #146**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #147**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['S9', 'CT', 'HA'])
# Street "turn" started. (community card = ['S9', 'CT', 'HA', 'C4'])
# Street "river" started. (community card = ['S9', 'CT', 'HA', 'C4', 'HK'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #148**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #149**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['H2', 'H6', 'SA'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1030, 'p2': 970})
# ********GAME LOOP #150**********
# Started the round 1
# Street "preflop" started. (community card = [])
# ...
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #948**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #949**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #950**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #951**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #952**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['DQ', 'H5', 'S2'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:980"
# "p2" declared "call:980"
# Street "turn" started. (community card = ['DQ', 'H5', 'S2', 'SK'])
# Street "river" started. (community card = ['DQ', 'H5', 'S2', 'SK', 'SJ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #953**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['D2', 'S8', 'H9'])
# Street "turn" started. (community card = ['D2', 'S8', 'H9', 'D8'])
# Street "river" started. (community card = ['D2', 'S8', 'H9', 'D8', 'CT'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #954**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['S5', 'H3', 'CK'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #955**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #956**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #957**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #958**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['H8', 'DK', 'C2'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:970"
# "p2" declared "call:970"
# Street "turn" started. (community card = ['H8', 'DK', 'C2', 'H3'])
# Street "river" started. (community card = ['H8', 'DK', 'C2', 'H3', 'D7'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #959**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['C5', 'C9', 'D8'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1030, 'p2': 970})
# ********GAME LOOP #960**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #961**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['DK', 'H8', 'D5'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #962**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #963**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['D2', 'CT', 'DK'])
# Street "turn" started. (community card = ['D2', 'CT', 'DK', 'SA'])
# Street "river" started. (community card = ['D2', 'CT', 'DK', 'SA', 'SJ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #964**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #965**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #966**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['C7', 'DQ', 'HJ'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:970"
# "p2" declared "call:970"
# Street "turn" started. (community card = ['C7', 'DQ', 'HJ', 'S3'])
# Street "river" started. (community card = ['C7', 'DQ', 'HJ', 'S3', 'D8'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #967**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #968**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #969**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['D9', 'SJ', 'C4'])
# Street "turn" started. (community card = ['D9', 'SJ', 'C4', 'DQ'])
# Street "river" started. (community card = ['D9', 'SJ', 'C4', 'DQ', 'C8'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #970**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['HT', 'S5', 'DQ'])
# Street "turn" started. (community card = ['HT', 'S5', 'DQ', 'C2'])
# Street "river" started. (community card = ['HT', 'S5', 'DQ', 'C2', 'HK'])
# "['p1']" won the round 1 (stack = {'p1': 2000, 'p2': 0})
# ********GAME LOOP #971**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['SA', 'C5', 'HT'])
# Street "turn" started. (community card = ['SA', 'C5', 'HT', 'CT'])
# Street "river" started. (community card = ['SA', 'C5', 'HT', 'CT', 'HQ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #972**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #973**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #974**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:30"
# "p2" declared "call:30"
# Street "flop" started. (community card = ['S9', 'S6', 'H9'])
# "p2" declared "call:0"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:970"
# "p2" declared "call:970"
# Street "turn" started. (community card = ['S9', 'S6', 'H9', 'DA'])
# Street "river" started. (community card = ['S9', 'S6', 'H9', 'DA', 'D6'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #975**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #976**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #977**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #978**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #979**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['C4', 'S9', 'DJ'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "turn" started. (community card = ['C4', 'S9', 'DJ', 'S8'])
# "p2" declared "call:0"
# ************ RL Player: Call ************
# "p1" declared "call:0"
# Street "river" started. (community card = ['C4', 'S9', 'DJ', 'S8', 'H3'])
# "p2" declared "call:0"
# ************ RL Player: Raise Min ************
# "p1" declared "raise:20"
# "p2" declared "call:20"
# "['p2']" won the round 1 (stack = {'p1': 960, 'p2': 1040})
# ********GAME LOOP #980**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['C4', 'SK', 'H5'])
# Street "turn" started. (community card = ['C4', 'SK', 'H5', 'CA'])
# Street "river" started. (community card = ['C4', 'SK', 'H5', 'CA', 'C7'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #981**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #982**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #983**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #984**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #985**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['CK', 'D2', 'SQ'])
# Street "turn" started. (community card = ['CK', 'D2', 'SQ', 'DJ'])
# Street "river" started. (community card = ['CK', 'D2', 'SQ', 'DJ', 'H5'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #986**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['H8', 'D4', 'DA'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #987**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #988**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #989**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['SQ', 'CK', 'S6'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #990**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #991**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #992**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #993**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #994**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Raise Max ************
# "p1" declared "raise:1000"
# "p2" declared "call:1000"
# Street "flop" started. (community card = ['D3', 'D9', 'C8'])
# Street "turn" started. (community card = ['D3', 'D9', 'C8', 'S8'])
# Street "river" started. (community card = ['D3', 'D9', 'C8', 'S8', 'DQ'])
# "['p2']" won the round 1 (stack = {'p1': 0, 'p2': 2000})
# ********GAME LOOP #995**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['S9', 'CK', 'ST'])
# "p2" declared "call:0"
# ************RL Player: Fold************
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 980, 'p2': 1020})
# ********GAME LOOP #996**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "call:20"
# ************ RL Player: Call ************
# "p1" declared "call:20"
# Street "flop" started. (community card = ['S3', 'D4', 'D8'])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1020, 'p2': 980})
# ********GAME LOOP #997**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #998**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})
# ********GAME LOOP #999**********
# Started the round 1
# Street "preflop" started. (community card = [])
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 1010, 'p2': 990})

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-56003a83dc40> in <module>
#       1 RLPokerPlayer = RLPokerAgent()
# ----> 2 BluffingPlayer = BluffingPlayer()
#       3 play_game(RLPokerPlayer, BluffingPlayer, "against Bluffing Player", 1000)
#
# TypeError: 'BluffingPlayer' object is not callable
