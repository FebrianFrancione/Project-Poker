# %%
from pypokerengine.api.game import setup_config, start_poker

# %run HonestPlayer.ipynb
# %run RLPokerPlayer.ipynb


#This is the game loop
#Run this file to get the agents to play against each other

config = setup_config(max_round=15, initial_stack=100, small_blind_amount=5)
config.register_player(name="p1", algorithm=HonestPlayer())
config.register_player(name="p2", algorithm=RLPokerAgent())
game_result = start_poker(config, verbose=1)
# Out:
# Started the round 1
# Street "preflop" started. (community card = [])
# ************ RL Player: Raise Max ************
# "p2" declared "raise:100"
# ['D7', 'H4']
# []
# "p1" declared "fold:0"
# "['p2']" won the round 1 (stack = {'p1': 90, 'p2': 110})
# 110
# Started the round 2
# Street "preflop" started. (community card = [])
# ['D9', 'C3']
# []
# "p1" declared "fold:0"
# "['p2']" won the round 2 (stack = {'p1': 85, 'p2': 115})
# 115
# Started the round 3
# Street "preflop" started. (community card = [])
# ************ RL Player: Raise Max ************
# "p2" declared "raise:115"
# ['CJ', 'HA']
# []
# "p1" declared "call:115"
# Street "flop" started. (community card = ['SA', 'C5', 'HQ'])
# Street "turn" started. (community card = ['SA', 'C5', 'HQ', 'HJ'])
# Street "river" started. (community card = ['SA', 'C5', 'HQ', 'HJ', 'H9'])
# "['p1']" won the round 3 (stack = {'p1': 170, 'p2': 30})
# 30
# Started the round 4
# Street "preflop" started. (community card = [])
# ['SA', 'D4']
# ...
